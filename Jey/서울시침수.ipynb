# %%
! pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.22 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from geopandas) (2.1.2)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from geopandas) (2.2.3)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.7.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.6-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading pyogrio-0.10.0-cp312-cp312-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ----- ---------------------------------- 2.4/16.2 MB 12.2 MB/s eta 0:00:02
#    ------------ --------------------------- 5.0/16.2 MB 12.1 MB/s eta 0:00:01
#    ------------------ --------------------- 7.3/16.2 MB 11.9 MB/s eta 0:00:01
#    ------------------------ --------------- 10.0/16.2 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 12.3/16.2 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 14.9/16.2 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 11.4 MB/s eta 0:00:00
# Downloading pyproj-3.7.0-cp312-cp312-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --------------- ------------------------ 2.4/6.2 MB 12.2 MB/s eta 0:00:01
#    ------------------------------ --------- 4.7/6.2 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 11.2 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 8.4 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.10.0 pyproj-3.7.0 shapely-2.0.6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import geopandas as gpd
from shapely.geometry import Point

# %%
import os

os.environ["SHAPE_RESTORE_SHX"] = "YES"

# %%
# 맷플롯립 한글 사용 가능
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
gdf = gpd.read_file('2023_서울시_침수흔적도.shp')

# %%
type(gdf.iloc[:10])
gdf.shape
# Out:
# (211, 1)

# %%
gdf[:10].plot(figsize=(10, 10), edgecolor='black', cmap='viridis')
plt.show()
